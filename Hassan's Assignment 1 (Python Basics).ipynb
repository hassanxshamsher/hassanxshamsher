# %% [markdown]
# # Part -1 Python Basics (Variables)

# %% [markdown]
# 1. Print Your Name with your Father name and Date of birth using suitable escape sequence charactor

# %%
name = "Hassan Alam"
father = "Shamsher Ali Alam"
birth = "7th July, 1998"
# Enhanced version with explanation
print("My name is", name, "my father name is", father, "I was born on", birth + ".")
# Out:
# My name is Hassan Alam my father name is Shamsher Ali Alam I was born on 7th July, 1998.

# %% [markdown]
# 2. Write your small bio using variables and print it using print function

# %%
name = "Hassan Alam"
city = "was born and raised in busiest city of Pakistan, Karachi"
interests = "Reading Fiction and Spionage Literature and Strenght Exercises"
print(f"My name is {name}. I {city}. My Hobbies are {interests}")
# Out:
# My name is Hassan Alam. I was born and raised in busiest city of Pakistan, Karachi. My Hobbies are Reading Fiction and Spionage Literature and Strenght Exercises

# %% [markdown]
# 3. Write a program in which use all the operators we can use in Python

# %%
num1 = 10
num2 = 5
sum = num1 + num2
print("Sum:", sum)
diff = num1 - num2
print("Difference:", diff)
product = num1 * num2
print("Product:", product)
div_float = num1 / num2
print("Division:", div_float)
modulo = num1 % num2
print("Modulo:", modulo)
power = num1 ** num2
print("Power:", power)
# Out:
# Sum: 15
# Difference: 5
# Product: 50
# Division: 2.0
# Modulo: 0
# Power: 100000

# %% [markdown]
# 4. Completes the following steps of small task:
#     - Mention Marks of English , Islamiat and Maths out of 100 in 3 different variables
#     - Mention Variable of Total Marks and assign 300 to it
#     - Calculate Percentage

# %%
english = int(input("Enter your English marks (out of 100): "))
islamiat = int(input("Enter your Islamiat marks (out of 100): "))
maths = int(input("Enter your Maths marks (out of 100): "))
total_marks = 300
percentage = (english + islamiat + maths) / total_marks * 100
print("Your percentage is:", percentage, "%")
# Out:
# Enter your English marks (out of 100):  70
# Enter your Islamiat marks (out of 100):  75
# Enter your Maths marks (out of 100):  73
# Your percentage is: 72.66666666666667 %

# %% [markdown]
# # Part -2 Python Basics (Conditional Statements)

# %% [markdown]
# 1) A company decided to give bonus of 5% to employee if his/her year of service is more than 5 years.
# Ask user for their salary and year of service and print the net bonus amount.

# %%
salary = float(input("Enter your salary: "))
service = int(input("Enter your years of service: "))
bonus = 0
if service > 5:
    bonus = salary * 0.05
net_bonus = bonus
print("Your net bonus amount is:", net_bonus)
# Out:
# Enter your salary:  60000
# Enter your years of service:  6
# Your net bonus amount is: 3000.0

# %% [markdown]
# 2) Write a program to check whether a person is eligible for voting or not. (accept age from user) if age is greater than 17 eligible otherwise not eligible

# %%
age = int(input("Enter your age: "))
if age >= 18:
    print("You are eligible to vote.")
else:
    print("You are not eligible to vote yet.")
# Out:
# Enter your age:  22
# You are eligible to vote.

# %% [markdown]
# 3) Write a program to check whether a number entered by user is even or odd.

# %%
num = int(input("Enter a number: "))
if num % 2 == 0:
  print("The number", num, "is even.")
else:
  print("The number", num, "is odd.")
# Out:
# Enter a number:  7
# The number 7 is odd.

# %% [markdown]
# 4) Write a program to check whether a number is divisible by 7 or not.
# Show Answer

# %%
num = int(input("Enter a number: "))
divisible_by_7 = num % 7 == 0
print("The number is divisible by 7" if divisible_by_7 else "The number is not divisible by 7")
# Out:
# Enter a number:  14
# The number is divisible by 7

# %% [markdown]
# 5) Write a program to display
# "Hello" if a number entered by user is a multiple of five , otherwise print "Bye".

# %%
num = int(input("Enter a number: "))
multiple_of_five = num % 5 == 0
print("Hello" if multiple_of_five else "Bye")
# Out:
# Enter a number:  55
# Hello

# %% [markdown]
# 7) Write a program to display the last digit of a number.

# %%
#Type your code here

# %% [markdown]
# 9) Take values of length and breadth of a rectangle from user and print if it is square or rectangle.

# %%
#Type your code here

# %% [markdown]
# 10) Take two int values from user and print greatest among them.

# %%
first = int(input("Enter the first number: "))
second = int(input("Enter the second number: "))
greatest_num = first if first >= second else second
print("The greatest number is:", greatest_num)
# Out:
# Enter the first number:  45
# Enter the second number:  44
# The greatest number is: 45

# %% [markdown]
# 11) A shop will give discount of 10% if the cost of purchased quantity is more than 1000.
# Ask user for quantity
# Suppose, one unit will cost 100.
# Judge and print total cost for user.

# %%
#Type your code here

# %% [markdown]
# 12) A school has following rules for grading system:
#
# a. Below 25 - F
#
# b. 25 to 45 - E
#
# c. 45 to 50 - D
#
# d. 50 to 60 - C
#
# e. 60 to 80 - B
#
# f. Above 80 - A
#
# Ask user to enter marks and print the corresponding grade.

# %%
marks = int(input("Enter your marks (0-100): "))
grade = None
if marks >= 80:
    grade = "A"
elif marks >= 60:
    grade = "B"
elif marks >= 50:
    grade = "C"
elif marks >= 45:
    grade = "D"
elif marks >= 25:
    grade = "E"
else:
    grade = "F"

if grade is not None:
    print("Your grade is:", grade)
else:
    print("Invalid marks. Please enter a value between 0 and 100.")
# Out:
# Enter your marks (0-100):  75
# Your grade is: B

# %% [markdown]
# 14)A student will not be allowed to sit in exam if his/her attendence is less than 75%.
#
# Take following input from user
#
# - Number of classes held
#
# - Number of classes attended.
#
# And print
#
# - percentage of class attended
#
# - Is student is allowed to sit in exam or not.

# %%
#Type your code here

# %% [markdown]
# 15) Modify the above question to allow student to sit if he/she has medical cause. Ask user if he/she has medical cause or not ( 'Y' or 'N' ) and print accordingly.

# %%
#Type your code here

# %% [markdown]
# 16) Write a program to check if a year is leap year or not.
#
# If a year is divisible by 4 then it is leap year but if the year is century year like 2000, 1900, 2100 then it must be divisible by 400.

# %%
#Type your code here

# %% [markdown]
# 17) Ask user to enter age, gender ( M or F ), marital status ( Y or N ) and then using following rules print their place of service.
#
# if employee is female, then she will work only in urban areas.
#
# if employee is a male and age is in between 20 to 40 then he may work in anywhere
#
# if employee is male and age is in between 40 t0 60 then he will work in urban areas only.
#
# And any other input of age should print "ERROR"

# %%
#Type your code here

# %% [markdown]
# 6) Write a program to calculate the electricity bill (accept number of unit from user) according to the following criteria :
#      Unit                                                     Price
# uptp 100 units                                             no charge
# Next 200 units                                              Rs 5 per unit
# After 200 units                                             Rs 10 per unit
# (For example if input unit is 350 than total bill amount is Rs.3500
# (For example if input unit is 97 than total bill amount is Rs.0
# (For example if input unit is 150 than total bill amount is Rs.750

# %% [markdown]
# 13) Take input of age of 3 people by user and determine oldest and youngest among them.

# %%
#Type your code here
